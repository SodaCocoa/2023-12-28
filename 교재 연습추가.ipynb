# %%
#오름차순
food=['피자', '치킨' , '스테이크','된찌','파스타','감자칩']
food.sort()
print('정렬 후:', food)
# Out:
# 정렬 후: ['감자칩', '된찌', '스테이크', '치킨', '파스타', '피자']

# %%
#내림차순
food=['피자', '치킨' , '스테이크','된찌','파스타','감자칩']
food.sort(reverse=True)
print('정렬 후:', food)
# Out:
# 정렬 후: ['피자', '파스타', '치킨', '스테이크', '된찌', '감자칩']

# %%
#내림차순 정렬 후 큰수 두개 슬라이싱
spending_6mon = [25,36,8,53,24,56]
spending_6mon.sort(reverse=True)
print(spending_6mon[0:2])
# Out:
# [56, 53]

# %%
#내림차순 정렬 후 작은수 두개 슬라이싱
spending_6mon = [25,36,8,53,24,56]
spending_6mon.sort(reverse=True)
print(spending_6mon[-2:])
# Out:
# [24, 8]

# %%
#최대값, 최솟값 출력
print(max(spending_6mon), min(spending_6mon))
# Out:
# 56 8

# %%
print(sum(spending_6mon))
# Out:
# 202

# %%
#24의 인덱스 찾기
print(spending_6mon.index(24))
# Out:
# 4

# %%
#구구단 백준 2739
n = int(input())

for i in range(1,10):  # 1~9
    print(n, '*', i, '=', n*i)
# Out:
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18

# %%
numList = []
for i in range(9):
    numList.append(int(input()))

print(max(numList))
print(numList.index(max(numList))+1)
# Out:
# 9
# 9
# <function max>

# %%
#문자열 입력후 그자리수 추출
s = input()
i = int(input())
print(s[i-1])
# Out:
# r

# %%
#개수 정한후 그 숫자만큼 정수 입력후 합 구하기
t = int(input())  # 테스트 케이스 개수 t를 입력받음

for _ in range(t):  # t 만큼 반복
    a,b = map(int,input().split())
    print(a+b)
# Out:
# 2
# 5
# 7
# 17
# 7

# %%
# 무한 루프를 사용하여 여러 개의 테스트 케이스를 입력받음
while True:
    try:
        # A와 B를 입력받음
        A, B = map(int, input().split())

        # A와 B를 더한 결과를 출력
        print(A + B)

    # 입력이 끝나면 종료
    except EOFError:
        break
# Out:
# 2
# 5
# 4
# 2
# 4
# 3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 5
#       2 while True:
#       3     try:
#       4         # A와 B를 입력받음
# ----> 5         A, B = map(int, input().split())
#       7         # A와 B를 더한 결과를 출력
#       8         print(A + B)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
data=[]
for i in range(9):
    data.append(i+3)
data
# Out:
# [3, 4, 5, 6, 7, 8, 9, 10, 11]

# %%
food1=['쌈밥','치킨','피자']
food2=['사과','아이스크림','커피']

data=[]
for x in food1:
    #print('-> 메뉴는',x1)
    for y in food2:
        #print('후식은', x2)
        data.append((x,y))
data
# Out:
# [('쌈밥', '사과'),
#  ('쌈밥', '아이스크림'),
#  ('쌈밥', '커피'),
#  ('치킨', '사과'),
#  ('치킨', '아이스크림'),
#  ('치킨', '커피'),
#  ('피자', '사과'),
#  ('피자', '아이스크림'),
#  ('피자', '커피')]

# %%
#컴프리헨션
food1 = ['쌈밥', '치킨', '피자']
food2 = ['사과', '아이스크림', '커피']

data = [(x, y) for x in food1 for y in food2]

# %%
#만약 아래와 같이 블로그에서 취미아 관련된 자료를
txt=['a  rkrk  a dfds as sdf dfs d',
     'as sd ss s s q r f d s g',
     ' c v ed']
tmp=[]
for i in txt:
    splitTxt=i.split(' ')
    #print(splitTxt)
    tmp.append(splitTxt)
tmp
# Out:
# [['a', '', 'rkrk', '', 'a', 'dfds', 'as', 'sdf', 'dfs', 'd'],
#  ['as', 'sd', 'ss', 's', 's', 'q', 'r', 'f', 'd', 's', 'g'],
#  ['', 'c', 'v', 'ed']]

# %%
연설문1='''However, let us not rest on our laurels. The world around us is dynamic and ever-changing. It requires us to adapt, innovate, and embrace new perspectives. '''

# %%
# !pip install wordcloud matplotlib
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: matplotlib in c:\users\bluecom011\miniconda3\envs\openai\lib\site-packages (3.8.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\bluecom011\miniconda3\envs\openai\lib\site-packages (from wordcloud) (1.26.2)
# Requirement already satisfied: pillow in c:\users\bluecom011\miniconda3\envs\openai\lib\site-packages (from wordcloud) (10.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bluecom011\miniconda3\envs\openai\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\bluecom011\miniconda3\envs\openai\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bluecom011\miniconda3\envs\openai\lib\site-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bluecom011\miniconda3\envs\openai\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\bluecom011\miniconda3\envs\openai\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bluecom011\miniconda3\envs\openai\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bluecom011\miniconda3\envs\openai\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\bluecom011\miniconda3\envs\openai\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading wordcloud-1.9.3-cp312-cp312-win_amd64.whl (301 kB)
#    ---------------------------------------- 0.0/301.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/301.4 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/301.4 kB 660.6 kB/s eta 0:00:01
#    ------------------- -------------------- 143.4/301.4 kB 1.4 MB/s eta 0:00:01
#    --------------------------- ------------ 204.8/301.4 kB 1.6 MB/s eta 0:00:01
#    ------------------------------------ --- 276.5/301.4 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 301.4/301.4 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3

# %%
pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.5 MB 1.4 MB/s eta 0:00:02
#       --------------------------------------- 0.0/1.5 MB 1.4 MB/s eta 0:00:02
#       --------------------------------------- 0.0/1.5 MB 1.4 MB/s eta 0:00:02
#       --------------------------------------- 0.0/1.5 MB 1.4 MB/s eta 0:00:02
#       --------------------------------------- 0.0/1.5 MB 1.4 MB/s eta 0:00:02
#       --------------------------------------- 0.0/1.5 MB 1.4 MB/s eta 0:00:02
#       --------------------------------------- 0.0/1.5 MB 1.4 MB/s eta 0:00:02
#       --------------------------------------- 0.0/1.5 MB 1.4 MB/s eta 0:00:02
#       --------------------------------------- 0.0/1.5 MB 1.4 MB/s eta 0:00:02
#       --------------------------------------- 0.0/1.5 MB 1.4 MB/s eta 0:00:02
#       --------------------------------------- 0.0/1.5 MB 1.4 MB/s eta 0:00:02
#       --------------------------------------- 0.0/1.5 MB 1.4 MB/s eta 0:00:02
#       --------------------------------------- 0.0/1.5 MB 1.4 MB/s eta 0:00:02
#       --------------------------------------- 0.0/1.5 MB 1.4 MB/s eta 0:00:02
#       --------------------------------------- 0.0/1.5 MB 1.4 MB/s eta 0:00:02
#       --------------------------------------- 0.0/1.5 MB 1.4 MB/s eta 0:00:02
#      - -------------------------------------- 0.1/1.5 MB 65.6 kB/s eta 0:00:23
#      ---- ----------------------------------- 0.2/1.5 MB 197.9 kB/s eta 0:00:07
#      ------------- -------------------------- 0.5/1.5 MB 540.8 kB/s eta 0:00:02
#      ----------------------- ---------------- 0.9/1.5 MB 950.8 kB/s eta 0:00:01
#      -------------------------------- ------- 1.2/1.5 MB 1.2 MB/s eta 0:00:01
#      -------------------------------- ------- 1.2/1.5 MB 1.2 MB/s eta 0:00:01
#      ---------------------------------------  1.5/1.5 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------- 1.5/1.5 MB 1.4 MB/s eta 0:00:00
# Collecting click (from nltk)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting joblib (from nltk)
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2023.12.25-cp312-cp312-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      ---------------------------------------- 42.0/42.0 kB 2.1 MB/s eta 0:00:00
# Collecting tqdm (from nltk)
#   Downloading tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\bluecom011\miniconda3\envs\openai\lib\site-packages (from click->nltk) (0.4.6)
# Downloading regex-2023.12.25-cp312-cp312-win_amd64.whl (268 kB)
#    ---------------------------------------- 0.0/268.9 kB ? eta -:--:--
#    --------------------------------------- 268.9/268.9 kB 16.2 MB/s eta 0:00:00
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ---------------------------------------- 0.0/97.9 kB ? eta -:--:--
#    ---------------------------------------- 97.9/97.9 kB 5.8 MB/s eta 0:00:00
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ---------------------------------------- 0.0/302.2 kB ? eta -:--:--
#    ---------------------------------------  297.0/302.2 kB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 302.2/302.2 kB 4.6 MB/s eta 0:00:00
# Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ---------------------------------------- 78.3/78.3 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: tqdm, regex, joblib, click, nltk
# Successfully installed click-8.1.7 joblib-1.3.2 nltk-3.8.1 regex-2023.12.25 tqdm-4.66.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Collecting pandasNote: you may need to restart the kernel to use updated packages.
#
#   Downloading pandas-2.1.4-cp312-cp312-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\bluecom011\miniconda3\envs\openai\lib\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bluecom011\miniconda3\envs\openai\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ---------------------------------------- 0.0/341.8 kB ? eta -:--:--
#      ---- ----------------------------------- 41.0/341.8 kB ? eta -:--:--
#      ------------------ ------------------- 163.8/341.8 kB 3.3 MB/s eta 0:00:01
#      --------------------- ---------------- 194.6/341.8 kB 2.4 MB/s eta 0:00:01
#      -------------------------------------  337.9/341.8 kB 2.6 MB/s eta 0:00:01
#      -------------------------------------- 341.8/341.8 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\bluecom011\miniconda3\envs\openai\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.1.4-cp312-cp312-win_amd64.whl (10.5 MB)
#    ---------------------------------------- 0.0/10.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.5 MB 7.9 MB/s eta 0:00:02
#    - -------------------------------------- 0.4/10.5 MB 5.5 MB/s eta 0:00:02
#    - -------------------------------------- 0.4/10.5 MB 5.5 MB/s eta 0:00:02
#    -- ------------------------------------- 0.6/10.5 MB 3.2 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/10.5 MB 3.8 MB/s eta 0:00:03
#    --- ------------------------------------ 1.0/10.5 MB 3.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.2/10.5 MB 4.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.5/10.5 MB 4.2 MB/s eta 0:00:03
#    ------ --------------------------------- 1.7/10.5 MB 4.3 MB/s eta 0:00:03
#    ------- -------------------------------- 1.9/10.5 MB 4.1 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/10.5 MB 4.1 MB/s eta 0:00:03
#    --------- ------------------------------ 2.4/10.5 MB 4.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/10.5 MB 4.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.9/10.5 MB 4.5 MB/s eta 0:00:02
#    ------------ --------------------------- 3.3/10.5 MB 4.7 MB/s eta 0:00:02
#    -------------- ------------------------- 3.7/10.5 MB 4.9 MB/s eta 0:00:02
#    -------------- ------------------------- 3.8/10.5 MB 5.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.2/10.5 MB 5.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.6/10.5 MB 5.2 MB/s eta 0:00:02
#    ------------------ --------------------- 4.8/10.5 MB 5.2 MB/s eta 0:00:02
#    ------------------- -------------------- 5.1/10.5 MB 5.4 MB/s eta 0:00:02
#    -------------------- ------------------- 5.4/10.5 MB 5.3 MB/s eta 0:00:01
#    -------------------- ------------------- 5.5/10.5 MB 5.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.8/10.5 MB 5.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.8/10.5 MB 5.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.9/10.5 MB 4.9 MB/s eta 0:00:01
#    ------------------------ --------------- 6.4/10.5 MB 5.1 MB/s eta 0:00:01
#    ------------------------- -------------- 6.6/10.5 MB 5.2 MB/s eta 0:00:01
#    --------------------------- ------------ 7.1/10.5 MB 5.3 MB/s eta 0:00:01
#    --------------------------- ------------ 7.1/10.5 MB 5.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.5/10.5 MB 5.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.9/10.5 MB 5.3 MB/s eta 0:00:01
#    ------------------------------- -------- 8.2/10.5 MB 5.4 MB/s eta 0:00:01
#    --------------------------------- ------ 8.9/10.5 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.0/10.5 MB 5.6 MB/s eta 0:00:01
#    ------------------------------------- -- 9.9/10.5 MB 5.9 MB/s eta 0:00:01
#    -------------------------------------- - 10.2/10.5 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.5 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.5 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.5/10.5 MB 5.6 MB/s eta 0:00:00
# Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#    ---------------------------------------- 0.0/502.5 kB ? eta -:--:--
#    ---- ----------------------------------- 61.4/502.5 kB ? eta -:--:--
#    ---------------------------------------  501.8/502.5 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 502.5/502.5 kB 5.3 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.1.4 pytz-2023.3.post1 tzdata-2023.3

# %%
#위에 연설문중 가장 많이 나온 단어
from collections import Counter

def extract_most_common_words(text, num_words=5):
    # 소문자로 변환하고 특수 문자 제거
    cleaned_text = ''.join(char.lower() if char.isalpha() or char.isspace() else ' ' for char in text)

    # 단어 빈도 계산
    word_counts = Counter(cleaned_text.split())

    # 가장 많이 나온 단어 추출
    most_common_words = word_counts.most_common(num_words)

    return most_common_words

# 예시 텍스트
speech_text = """
Thank you for joining me today as we address a matter of utmost urgency and global significance – the issue of climate change.
The state of our planet demands our attention, collective action, and unwavering commitment to sustainable practices.
"""

# 가장 많이 나온 단어 추출 (상위 5개)
most_common_words = extract_most_common_words(speech_text, num_words=5)

# 결과 출력
print("Most common words:")
for word, count in most_common_words:
    print(f"{word}: {count}")
# Out:
# Most common words:
# of: 3
# and: 2
# the: 2
# our: 2
# thank: 1

# %%
#3글자이상단어 re.findAll없이 만든코드
from collections import Counter

def extract_most_common_words(text, num_words=5, min_word_length=3):
    # 소문자로 변환하고 특수 문자 제거
    cleaned_text = ''.join(char.lower() if char.isalpha() or char.isspace() else ' ' for char in text)

    # 단어 빈도 계산
    word_counts = Counter(cleaned_text.split())

    # 3글자 이상인 단어만 추출
    filtered_words = {word: count for word, count in word_counts.items() if len(word) >= min_word_length}

    # 가장 많이 나온 단어 추출
    most_common_words = Counter(filtered_words).most_common(num_words)

    return most_common_words

# 예시 텍스트
speech_text = """
Thank you for joining me today as we address a matter of utmost urgency and global significance – the issue of climate change.
The state of our planet demands our attention, collective action, and unwavering commitment to sustainable practices.
"""

# 가장 많이 나온 단어 추출 (상위 5개, 3글자 이상)
most_common_words = extract_most_common_words(speech_text, num_words=5, min_word_length=3)

# 결과 출력
print("Most common words (3 letters or more):")
for word, count in most_common_words:
    print(f"{word}: {count}")
# Out:
# Most common words (3 letters or more):
# and: 2
# the: 2
# our: 2
# thank: 1
# you: 1

# %%
#연설문 워드클라우드로
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 주어진 텍스트
speech_text = """
Thank you for joining me today as we address a matter of utmost urgency and global significance – the issue of climate change. 
The state of our planet demands our attention, collective action,
 and unwavering commitment to sustainable practices.
"""

# 워드클라우드 생성
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

# 시각화
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# 워드클라우드 막대그래프 시각화

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd

# 주어진 텍스트
speech_text = """
today Thank you for joining our today as we address a matter of utmost urgency and global significance – the today issue of climate change.
The state of our planet demands our attention, collective action, and unwavering commitment to sustainable practices.
"""

# 워드클라우드 생성
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(speech_text)

# 시각화
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# 단어 빈도 막대그래프 생성
word_counts = pd.Series(wordcloud.words_)

# 막대그래프 시각화
plt.figure(figsize=(5, 3))
word_counts.sort_values().plot(kind='barh', color='green')
plt.title('Word Frequency in Speech')
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.show()

# %%
#연설문이 많을경우 각각의 워드클라우드
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 주어진 텍스트
speech_textList = ["""
As we glance back at the chapters of our history, we see a narrative shaped by the dedication and hard work of countless individuals.
 Our journey, marked by both triumphs and challenges,
 'has brought us to this pivotal juncture. 
 It is a testament to the resilience and determination that define our collective spirit.
""", 'In this ever-evolving world, we are confronted with new opportunities and complexities. ', 
'Each of us plays a vital role in contributing to the tapestry of our shared future']

for speech_text in speech_textList:
# 워드클라우드 생성
    wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

# 시각화
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()
